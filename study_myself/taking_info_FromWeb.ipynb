# %%
#import necessary modül
import requests
from bs4 import BeautifulSoup

# %%
data =requests.get("https://www.lego.com/tr-tr/categories/keyrings")
data.content
# Out:
# b'<!DOCTYPE html><html lang="tr"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="manifest" href="/site.webmanifest"/><meta name="msapplication-TileImage" content="/lego-logo-144.png"/><link rel="icon" type="image/png" sizes="512x512" href="/lego-logo-512.png"/><link rel="icon" type="image/png" sizes="384x384" href="/lego-logo-384.png"/><link rel="icon" type="image/png" sizes="256x256" href="/lego-logo-256.png"/><link rel="icon" type="image/png" sizes="192x192" href="/lego-logo-192.png"/><link rel="icon" type="image/png" sizes="180x180" href="/lego-logo-180.png"/><link rel="icon" type="image/png" sizes="167x167" href="/lego-logo-167.png"/><link rel="icon" type="image/png" sizes="152x152" href="/lego-logo-152.png"/><link rel="icon" type="image/png" sizes="144x144" href="/lego-logo-144.png"/><link rel="icon" type="image/png" sizes="120x120" href="/lego-logo-120.png"/><link rel="icon" type="image/png" sizes="96x96" href="/lego-
# ...

# %%
soup= BeautifulSoup(data.content)

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
soup.find_all("a")
# Out:
# [<a class="Linksstyles__AnchorButton-sc-684acv-1 hMtCcz MainMenustyles__KidsLink-dniuii-5 kznbHA" href="https://kids.lego.com"><span class="Icon__Placeholder-lm07h6-2 leszCV"></span>Oyun Alanı</a>,
#  <a class="Linksstyles__Anchor-sc-684acv-0 friqQc MainMenustyles__HighlightedLink-dniuii-1 dptUhA" data-analytics-title="Christmas" data-test="Christmas" href="/tr-tr/holiday-gifts" target=""><span class="Markup__StyledMarkup-nc8x20-0 epIXnJ">Yeni yıl</span></a>,
#  <a class="Linksstyles__Anchor-sc-684acv-0 friqQc Liststyles__StyledLink-sc-114bngs-3 gdvOoQ" data-analytics-title="home" data-test="home" href="/tr-tr"><div class="Liststyles__TextWrapper-sc-114bngs-5 PKwCM"><span class="Text__BaseText-sc-13i1y3k-0 fmpRwF Liststyles__StyledText-sc-114bngs-4 idAzCA"><span class="Markup__StyledMarkup-nc8x20-0 epIXnJ">Home</span></span></div></a>,
# ...

# %%
linkler = soup.find_all("a")
for link in linkler:
    print(link)
# Out:
# <a class="Linksstyles__AnchorButton-sc-684acv-1 hMtCcz MainMenustyles__KidsLink-dniuii-5 kznbHA" href="https://kids.lego.com"><span class="Icon__Placeholder-lm07h6-2 leszCV"></span>Oyun Alanı</a>
# <a class="Linksstyles__Anchor-sc-684acv-0 friqQc MainMenustyles__HighlightedLink-dniuii-1 dptUhA" data-analytics-title="Christmas" data-test="Christmas" href="/tr-tr/holiday-gifts" target=""><span class="Markup__StyledMarkup-nc8x20-0 epIXnJ">Yeni yıl</span></a>
# <a class="Linksstyles__Anchor-sc-684acv-0 friqQc Liststyles__StyledLink-sc-114bngs-3 gdvOoQ" data-analytics-title="home" data-test="home" href="/tr-tr"><div class="Liststyles__TextWrapper-sc-114bngs-5 PKwCM"><span class="Text__BaseText-sc-13i1y3k-0 fmpRwF Liststyles__StyledText-sc-114bngs-4 idAzCA"><span class="Markup__StyledMarkup-nc8x20-0 epIXnJ">Home</span></span></div></a>
# ...

# %%
for link in linkler:
    print(link.get("href"))
# Out:
# https://kids.lego.com
# /tr-tr/holiday-gifts
# /tr-tr
# /tr-tr/categories/new-sets-and-products
# /tr-tr/categories/home-decor
# /tr-tr/categories/coming-soon
# /tr-tr/themes/architecture
# /tr-tr/themes/lego-batman-sets
# /tr-tr/themes/brickheadz
# /tr-tr/themes/brick-sketches
# /tr-tr/themes/city
# /tr-tr/themes/classic
# /tr-tr/themes/creator-3-in-1
# /tr-tr/themes/creator-expert
# /tr-tr/themes/dc
# /tr-tr/themes/disney
# /tr-tr/themes/dots
# /tr-tr/themes/duplo
# /tr-tr/themes/friends
# /tr-tr/themes/harry-potter
# /tr-tr/themes/ideas
# /tr-tr/themes/jurassic-world
# /tr-tr/themes/animal-crossing
# /tr-tr/themes/art
# /tr-tr/themes/avatar
# /tr-tr/themes/dreamzzz
# /tr-tr/themes/gabbys-dollhouse
# /tr-tr/themes/lego-icons
# /tr-tr/themes/indiana-jones
# /tr-tr/themes/super-mario
# /tr-tr/themes/lord-of-the-rings
# /tr-tr/themes/marvel
# /tr-tr/themes/minecraft
# /tr-tr/themes/minifigures
# /tr-tr/themes/monkie-kid
# /tr-tr/themes/ninjago
# /tr-tr/themes/overwatch
# ...

# %%
for link in linkler:
    print(link.text)
# Out:
# Oyun Alanı
# Yeni yıl
# Home
# Yeni
# Ev Dekoru
# Çok yakında
# Architecture
# Batman™
# BrickHeadz
# Brick Sketches™
# City
# Classic
# Creator 3in1
# Creator Expert
# DC
# Disney™
# DOTS
# DUPLO®
# Friends
# Harry Potter™
# Ideas
# Jurassic World
# LEGO® Animal Crossing™Yeni
# LEGO® Art
# LEGO® Avatar
# LEGO® DREAMZzz™Yeni
# LEGO® Gabby's DollhouseYeni
# LEGO® Icons
# LEGO® Indiana Jones™
# LEGO® Super Mario™
# Lord of the Rings™
# Marvel
# Minecraft®
# Mini Figürler
# Monkie Kid™
# NINJAGO®
# Overwatch®
# Powered UP
# Sonic the Hedgehog™
# Speed Champions
# Spider-Man
# Star Wars™
# Technic
# TÜM TEMALARI GÖSTER
# 1,5+
# 4+
# 6+
# 9+
# 13+
# 18+
# TÜM YAŞ ARALIKLARINI GÖSTER
# Anahtarlıklar
# LEGO® Su Şişeleri
# TÜM LEGO ÜRÜNLERİNİ GÖSTER
# Hayvanlar
# Yapılar
# Ejderhalar
# Fantastik
# Filmler
# Nasıl yapılacağını öğren
# Müzik
# Ninjalar
# Okul Öncesi
# Prensesler
# Gerçek Kahramanlar
# Robotlar
# Sezonluk
# Uzay
# Spor
# Trenler
# Seyahat
# TV Şovları
# Araçlar
# ...

# %%
import pandas as pd 
import snscrape.modules.twitter as sntwit

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
import numpy as np 
import pandas as pd 
import seaborn as sns

# %%
bird_df=pd.read_csv('C:\\veri_bilimi\\data\\birds.csv')

# %%
bird_df.head()
# Out:
#                            Name          ScientificName  \
# 0  Black-bellied whistling-duck  Dendrocygna autumnalis
# 1        Fulvous whistling-duck     Dendrocygna bicolor
# 2                    Snow goose      Anser caerulescens
# 3                  Ross's goose            Anser rossii
# 4   Greater white-fronted goose         Anser albifrons
#
#                 Category         Order    Family        Genus  \
# 0  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 1  Ducks/Geese/Waterfowl  Anseriformes  Anatidae  Dendrocygna
# 2  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 3  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
# 4  Ducks/Geese/Waterfowl  Anseriformes  Anatidae        Anser
#
#   ConservationStatus  MinLength  MaxLength  MinBodyMass  MaxBodyMass  \
# 0                 LC       47.0       56.0        652.0       1020.0
# 1                 LC       45.0       53.0        712.0       1050.0
# ...

# %%
bird_df.shape
# Out:
# (443, 13)

# %%
bird_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443 entries, 0 to 442
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                443 non-null    object
#  1   ScientificName      443 non-null    object
#  2   Category            443 non-null    object
#  3   Order               443 non-null    object
#  4   Family              443 non-null    object
#  5   Genus               443 non-null    object
#  6   ConservationStatus  443 non-null    object
#  7   MinLength           443 non-null    float64
#  8   MaxLength           443 non-null    float64
#  9   MinBodyMass         443 non-null    float64
#  10  MaxBodyMass         443 non-null    float64
#  11  MinWingspan         443 non-null    float64
#  12  MaxWingspan         443 non-null    float64
# dtypes: float64(6), object(7)
# memory usage: 45.1+ KB

# %%
bird_df.describe()
# Out:
#         MinLength   MaxLength  MinBodyMass   MaxBodyMass  MinWingspan  \
# count  443.000000  443.000000   443.000000    443.000000   443.000000
# mean    28.536682   35.441986   327.938262    667.009752    58.557901
# std     20.319887   27.539772   779.680106   1655.682564   104.602369
# min      7.000000    8.900000     2.000000      3.000000     8.000000
# 25%     13.750000   16.000000    18.000000     28.000000    23.000000
# 50%     20.500000   25.000000    55.000000     89.000000    38.000000
# 75%     39.000000   46.000000   332.000000    593.000000    72.750000
# max    138.000000  180.000000  9200.000000  14300.000000  1800.000000
#
#        MaxWingspan
# count   443.000000
# mean     67.524492
# std     126.673177
# min      10.600000
# 25%      25.000000
# 50%      42.000000
# 75%      83.000000
# max    2300.000000

# %%
bird_df.columns
# Out:
# Index(['Name', 'ScientificName', 'Category', 'Order', 'Family', 'Genus',
#        'ConservationStatus', 'MinLength', 'MaxLength', 'MinBodyMass',
#        'MaxBodyMass', 'MinWingspan', 'MaxWingspan'],
#       dtype='object')

# %%
bird_category=bird_df.groupby('Category').sum()

# %%
bird_category.head(4)
# Out:
#                                                                   Name  \
# Category
# Auks/Murres/Puffins  DovekieBlack guillemotLong-billed murreletAnci...
# Barn-owls                                                     Barn owl
# Cardinals/Allies     Summer tanagerScarlet tanagerWestern tanagerNo...
# Cormorants/Shags           Double-crested cormorantNeotropic cormorant
#
#                                                         ScientificName  \
# Category
# Auks/Murres/Puffins  Alle alleCepphus grylleBrachyramphus perdixSyn...
# Barn-owls                                                    Tyto alba
# Cardinals/Allies     Piranga rubraPiranga olivaceaPiranga ludovicia...
# Cormorants/Shags        Phalacrocorax auritusPhalacrocorax brasilianus
#
#                                                                  Order  \
# Category
# Auks/Murres/Puffins  CharadriiformesCharadriiformesCharadriiformesC...
# Barn-owls                                                 Strigiformes
# ...

# %%
bird_df_devided=bird_category[bird_category['MaxBodyMass'] > 12000]
bird_df_devided.head()
# Out:
#                                                                     Name  \
# Category
# Cranes                                      Sandhill craneWhooping crane
# Ducks/Geese/Waterfowl  Black-bellied whistling-duckFulvous whistling-...
# Gulls/Terns/Skimmers   Black-legged kittiwakeIvory gullSabine's gullB...
# Hawks/Eagles           White-tailed kiteSwallow-tailed kiteGolden eag...
# Loons                  Red-throated loonPacific loonCommon loonYellow...
#
#                                                           ScientificName  \
# Category
# Cranes                                 Antigone canadensisGrus americana
# Ducks/Geese/Waterfowl  Dendrocygna autumnalisDendrocygna bicolorAnser...
# Gulls/Terns/Skimmers   Rissa tridactylaPagophila eburneaXema sabiniCh...
# Hawks/Eagles           Elanus leucurusElanoides forficatusAquila chry...
# Loons                  Gavia stellataGavia pacificaGavia immerGavia a...
#
# ...

# %%
#Sort
df=bird_df_devided.sort_values(by=['MaxBodyMass'])
plt.barh(y=df.Family,
         width=bird_df_devided.MaxBodyMass,
         color=['blue','cyan'],
         edgecolor='black',
         linewidth=3
         )
# Out:
# <BarContainer object of 7 artists>

# %%
sns.histplot(data=bird_df,x='MaxBodyMass',kde=True)
# Out:
# <Axes: xlabel='MaxBodyMass', ylabel='Count'>

# %%
bird_category=bird_df.groupby('Family').sum()

# %%
bird_category.head()
# Out:
#                                                            Name  \
# Family
# Accipitridae  White-tailed kiteSwallow-tailed kiteGolden eag...
# Alaudidae                                           Horned lark
# Alcedinidae                                   Belted kingfisher
# Alcidae       DovekieBlack guillemotLong-billed murreletAnci...
# Anatidae      Black-bellied whistling-duckFulvous whistling-...
#
#                                                  ScientificName  \
# Family
# Accipitridae  Elanus leucurusElanoides forficatusAquila chry...
# Alaudidae                                  Eremophila alpestris
# Alcedinidae                                    Megaeryle alcyon
# Alcidae       Alle alleCepphus grylleBrachyramphus perdixSyn...
# Anatidae      Dendrocygna autumnalisDendrocygna bicolorAnser...
#
#                                                        Category  \
# Family
# Accipitridae  Hawks/EaglesHawks/EaglesHawks/EaglesHawks/Eagl...
# ...

# %%
bird_df.columns
# Out:
# Index(['Name', 'ScientificName', 'Category', 'Order', 'Family', 'Genus',
#        'ConservationStatus', 'MinLength', 'MaxLength', 'MinBodyMass',
#        'MaxBodyMass', 'MinWingspan', 'MaxWingspan'],
#       dtype='object')

# %%
bar2 = sns.barplot(
    x = 'MaxBodyMass',
    y = 'Family',
    data=bird_df[bird_df['MaxBodyMass'] > 8000],

    errorbar=None,
    color='lightblue'
    
    
)

# %%
sns.histplot(x='MaxBodyMass',data=bird_df[bird_df['MaxBodyMass'] > 8000],kde=True)
# Out:
# <Axes: xlabel='MaxBodyMass', ylabel='Count'>

# %%
sns.regplot(x = bird_df['MinWingspan'], y =bird_df['MaxWingspan'] )
# Out:
# <Axes: xlabel='MinWingspan', ylabel='MaxWingspan'>

# %%
sns.displot(x=bird_df['Genus'],y=bird_df['MinWingspan'],data=bird_df[:4])
sns.set_style("darkgrid")
# Out:
# c:\Users\zehra\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Name', y='MaxWingspan', data=bird_df[:10], color='blue', label='Max BodyMass')
sns.barplot(x='Name', y='MinWingspan', data=bird_df[:10], color='purple', label='Min BodyMass')
plt.xticks(rotation=50, ha='right')
plt.ylabel('BodyMass')
plt.legend()
plt.show()

# %%
sns.barplot(x='MaxBodyMass',y='MinBodyMass',data=bird_df[:5])
# Out:
# <Axes: xlabel='MaxBodyMass', ylabel='MinBodyMass'>

# %%
plt.figure(figsize=(18,8))

plt.title('Mass of body')
sns.scatterplot(x=bird_df.MaxBodyMass,
                y=bird_df.MinBodyMass,
                hue=bird_df.Category,
                s=50)
# Out:
# <Axes: title={'center': 'Mass of body'}, xlabel='MaxBodyMass', ylabel='MinBodyMass'>

# %%
plt.figure(figsize=(10,5))

plt.title('Mass of body')
sns.scatterplot(x=bird_df.MaxWingspan,
                y=bird_df.MinWingspan,
            
                s=50)
# Out:
# <Axes: title={'center': 'Mass of body'}, xlabel='MaxWingspan', ylabel='MinWingspan'>

# %%
sns.lineplot(x='Order', y='Family', data=bird_df)
plt.show()

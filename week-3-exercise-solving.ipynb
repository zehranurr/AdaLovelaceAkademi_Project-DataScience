# %%
base_url = 'C:\\veri_bilimi\\data\\covid\\'
infected_dataset_url ="C:\\veri_bilimi\\data\\covid\\time_series_covid19_confirmed_global (1).csv"
recovered_dataset_url = base_url + "time_series_covid19_recovered_global.csv"
deaths_dataset_url = base_url + "time_series_covid19_deaths_global.csv"

# %%
# Your code goes here
import pandas as pd
import numpy as np

# %%
infected = pd.read_csv(infected_dataset_url)
recorved = pd.read_csv(recovered_dataset_url)
deaths = pd.read_csv(deaths_dataset_url)

# %%
infected.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 0    22890    23546    24102    24766    25527
# 1     1385     1416     1464     1521     1590
# 2    10589    10698    10810    10919    11031
# 3      852      853      853      853      853
# 4      118      130      138      140      142
#
# [5 rows x 150 columns]

# %%
infected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 311.8+ KB

# %%
infected.shape
# Out:
# (266, 150)

# %%
infected.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    21.148043   22.538640    2.086466    2.458647    3.537594    5.390977
# std     24.909990   70.466256   27.279200   27.377862   34.083035   47.434934
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.907750  -18.093125    0.000000    0.000000    0.000000    0.000000
# 50%     23.488100   20.972650    0.000000    0.000000    0.000000    0.000000
# 75%     41.143200   77.191525    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        6/6/20  \
# count   266.000000   266.000000   266.000000   266.000000  ...  2.660000e+02
# mean      7.962406    11.003759    20.969925    23.180451  ...  2.594981e+04
# std      66.289178    89.313757   219.187744   220.524977  ...  1.333309e+05
# min       0.000000     0.000000     0.000000     0.000000  ...  0.000000e+00
# 25%       0.000000     0.000000     0.000000     0.000000  ...  1.572500e+02
# 50%       0.000000     0.000000     0.000000     0.000000  ...  9.535000e+02
# 75%       0.000000     0.000000     0.000000     0.000000  ...  7.094500e+03
# max    1058.000000  1423.000000  3554.000000  3554.000000  ...  1.926538e+06
#
#              6/7/20        6/8/20        6/9/20       6/10/20       6/11/20  \
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   2.637496e+04  2.676449e+04  2.722817e+04  2.773058e+04  2.825084e+04
# std    1.349130e+05  1.363934e+05  1.382464e+05  1.402889e+05  1.424252e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.572500e+02  1.572500e+02  1.580000e+02  1.625000e+02  1.650000e+02
# 50%    9.710000e+02  9.820000e+02  9.825000e+02  9.825000e+02  9.830000e+02
# 75%    7.117250e+03  7.427000e+03  7.706750e+03  8.005750e+03  8.194000e+03
# max    1.944309e+06  1.961781e+06  1.979868e+06  2.000702e+06  2.023590e+06
#
#             6/12/20       6/13/20       6/14/20       6/15/20
# count  2.660000e+02  2.660000e+02  2.660000e+02  2.660000e+02
# mean   2.873782e+04  2.924391e+04  2.974596e+04  3.020474e+04
# std    1.445871e+05  1.467117e+05  1.484660e+05  1.502466e+05
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.710000e+02  1.722500e+02  1.760000e+02  1.760000e+02
# 50%    1.005000e+03  1.005000e+03  1.005000e+03  1.005000e+03
# 75%    8.334500e+03  8.452500e+03  8.586500e+03  8.608750e+03
# max    2.048986e+06  2.074526e+06  2.094058e+06  2.114026e+06
#
# [8 rows x 148 columns]

# %%
infected['Province/State'].value_counts()
# Out:
# Province/State
# Australian Capital Territory    1
# Qinghai                         1
# Reunion                         1
# New Caledonia                   1
# Mayotte                         1
#                                ..
# Guizhou                         1
# Guangxi                         1
# Guangdong                       1
# Gansu                           1
# Saint Pierre and Miquelon       1
# Name: count, Length: 81, dtype: int64

# %%
infected[infected['Country/Region'] == 'China']
# Out:
#     Province/State Country/Region      Lat      Long  1/22/20  1/23/20  \
# 49           Anhui          China  31.8257  117.2264        1        9
# 50         Beijing          China  40.1824  116.4142       14       22
# 51       Chongqing          China  30.0572  107.8740        6        9
# 52          Fujian          China  26.0789  117.9874        1        5
# 53           Gansu          China  37.8099  101.0583        0        2
# 54       Guangdong          China  23.3417  113.4244       26       32
# 55         Guangxi          China  23.8298  108.7881        2        5
# 56         Guizhou          China  26.8154  106.8748        1        3
# 57          Hainan          China  19.1959  109.7453        4        5
# 58           Hebei          China  39.5490  116.1306        1        1
# 59    Heilongjiang          China  47.8620  127.7615        0        2
# 60           Henan          China  33.8820  113.6140        5        5
# 61       Hong Kong          China  22.3000  114.2000        0        2
# 62           Hubei          China  30.9756  112.2707      444      444
# 63           Hunan          China  27.6104  111.7088        4        9
# 64  Inner Mongolia          China  44.0935  113.9448        0        0
# 65         Jiangsu          China  32.9711  119.4550        1        5
# 66         Jiangxi          China  27.6140  115.7221        2        7
# 67           Jilin          China  43.6661  126.1923        0        1
# 68        Liaoning          China  41.2956  122.6085        2        3
# 69           Macau          China  22.1667  113.5500        1        2
# 70         Ningxia          China  37.2692  106.1655        1        1
# 71         Qinghai          China  35.7452   95.9956        0        0
# 72         Shaanxi          China  35.1917  108.8701        0        3
# 73        Shandong          China  36.3427  118.1498        2        6
# 74        Shanghai          China  31.2020  121.4491        9       16
# 75          Shanxi          China  37.5777  112.2922        1        1
# 76         Sichuan          China  30.6171  102.7103        5        8
# 77         Tianjin          China  39.3054  117.3230        4        4
# 78           Tibet          China  31.6927   88.0924        0        0
# 79        Xinjiang          China  41.1129   85.2401        0        2
# 80          Yunnan          China  24.9740  101.4870        1        2
# 81        Zhejiang          China  29.1832  120.0934       10       27
#
#     1/24/20  1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# 49       15       39       60       70  ...     991     991     991     991
# 50       36       41       68       80  ...     594     594     594     594
# 51       27       57       75      110  ...     579     579     579     579
# 52       10       18       35       59  ...     359     359     359     359
# 53        2        4        7       14  ...     139     139     139     139
# 54       53       78      111      151  ...    1602    1602    1604    1604
# 55       23       23       36       46  ...     254     254     254     254
# 56        3        4        5        7  ...     147     147     147     147
# 57        8       19       22       33  ...     170     170     170     170
# 58        2        8       13       18  ...     328     328     328     328
# 59        4        9       15       21  ...     947     947     947     947
# 60        9       32       83      128  ...    1276    1276    1276    1276
# 61        2        5        8        8  ...    1105    1106    1107    1107
# 62      549      761     1058     1423  ...   68135   68135   68135   68135
# 63       24       43       69      100  ...    1019    1019    1019    1019
# 64        1        7        7       11  ...     235     235     235     237
# 65        9       18       33       47  ...     653     653     653     653
# 66       18       18       36       72  ...     932     932     932     932
# 67        3        4        4        6  ...     155     155     155     155
# 68        4       17       21       27  ...     149     149     149     149
# 69        2        2        5        6  ...      45      45      45      45
# 70        2        3        4        7  ...      75      75      75      75
# 71        0        1        1        6  ...      18      18      18      18
# 72        5       15       22       35  ...     311     311     311     311
# 73       15       27       46       75  ...     792     792     792     792
# 74       20       33       40       53  ...     677     678     678     678
# 75        1        6        9       13  ...     198     198     198     198
# 76       15       28       44       69  ...     578     581     582     582
# 77        8       10       14       23  ...     193     193     193     194
# 78        0        0        0        0  ...       1       1       1       1
# 79        2        3        4        5  ...      76      76      76      76
# 80        5       11       16       26  ...     185     185     185     185
# 81       43       62      104      128  ...    1268    1268    1268    1268
#
#     6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 49      991      991      991      991      991      991
# 50      594      595      601      637      673      700
# 51      579      579      579      580      582      582
# 52      360      361      361      361      362      362
# 53      139      139      139      139      139      139
# 54     1607     1607     1608     1625     1625     1628
# 55      254      254      254      254      254      254
# 56      147      147      147      147      147      147
# 57      170      170      171      171      171      171
# 58      328      328      328      328      331      335
# 59      947      947      947      947      947      947
# 60     1276     1276     1276     1276     1276     1276
# 61     1107     1107     1108     1109     1109     1112
# 62    68135    68135    68135    68135    68135    68135
# 63     1019     1019     1019     1019     1019     1019
# 64      237      237      237      237      237      238
# 65      653      653      653      653      653      653
# 66      932      932      932      932      932      932
# 67      155      155      155      155      155      155
# 68      149      149      149      151      151      152
# 69       45       45       45       45       45       45
# 70       75       75       75       75       75       75
# 71       18       18       18       18       18       18
# 72      311      311      311      311      313      313
# 73      792      792      792      792      792      792
# 74      684      689      690      691      692      695
# 75      198      198      198      198      198      198
# 76      582      582      583      583      587      588
# 77      195      195      196      196      196      196
# 78        1        1        1        1        1        1
# 79       76       76       76       76       76       76
# 80      185      185      185      185      185      185
# 81     1268     1268     1268     1268     1268     1268
#
# [33 rows x 150 columns]

# %%
recorved.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...    1830    1875    2171    2651     3013
# 1        0        0        0  ...     925     938     945     960      980
# 2        0        0        0  ...    6631    6717    6799    6951     7074
# 3        0        0        0  ...     741     744     751     757      759
# 4        0        0        0  ...      24      24      38      38       40
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 0     3326     3928     4201     4725     5164
# 1     1001     1034     1039     1044     1055
# 2     7255     7322     7420     7606     7735
# 3      780      781      781      781      789
# 4       41       42       61       61       64
#
# [5 rows x 150 columns]

# %%
deaths.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...     327     357     369     384      405
# 1        0        0        0  ...      34      34      34      34       34
# 2        0        0        0  ...     698     707     715     724      732
# 3        0        0        0  ...      51      51      51      51       51
# 4        0        0        0  ...       4       4       4       4        4
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 0      426      446      451      471      478
# 1       35       36       36       36       36
# 2      741      751      760      767      777
# 3       51       51       51       51       51
# 4        5        5        6        6        6
#
# [5 rows x 150 columns]

# %%
recorved.info()#we cannot understand they are equal with this method
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 253 entries, 0 to 252
# Columns: 150 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(2)
# memory usage: 296.6+ KB

# %%
#then we used this function
infected.columns == recorved.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True])

# %%
all(infected.columns == recorved.columns)#same with above
# Out:
# True

# %%
#we will use this method thats why we create a method for it
def compare_columns(df1,df2):
    return all(df1.columns == df2.columns)

# %%
print(compare_columns(recorved,infected))
print(compare_columns(infected,deaths))
# Out:
# True
# True

# %%
infected.shape
# Out:
# (266, 150)

# %%
df_infected = infected.groupby('Country/Region').sum()

# %%
df_infected.head()
# Out:
#                Province/State      Lat     Long  1/22/20  1/23/20  1/24/20  \
# Country/Region
# Afghanistan                 0  33.0000  65.0000        0        0        0
# Albania                     0  41.1533  20.1683        0        0        0
# Algeria                     0  28.0339   1.6596        0        0        0
# Andorra                     0  42.5063   1.5218        0        0        0
# Angola                      0 -11.2027  17.8739        0        0        0
#
#                 1/25/20  1/26/20  1/27/20  1/28/20  ...  6/6/20  6/7/20  \
# Country/Region                                      ...
# Afghanistan           0        0        0        0  ...   19551   20342
# Albania               0        0        0        0  ...    1232    1246
# Algeria               0        0        0        0  ...   10050   10154
# Andorra               0        0        0        0  ...     852     852
# Angola                0        0        0        0  ...      88      91
#
#                 6/8/20  6/9/20  6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  \
# Country/Region
# Afghanistan      20917   21459    22142    22890    23546    24102    24766
# Albania           1263    1299     1341     1385     1416     1464     1521
# Algeria          10265   10382    10484    10589    10698    10810    10919
# Andorra            852     852      852      852      853      853      853
# Angola              92      96      113      118      130      138      140
#
#                 6/15/20
# Country/Region
# Afghanistan       25527
# Albania            1590
# Algeria           11031
# Andorra             853
# Angola              142
#
# [5 rows x 149 columns]

# %%
df_infected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 188 entries, Afghanistan to Zimbabwe
# Columns: 149 entries, Province/State to 6/15/20
# dtypes: float64(2), int64(146), object(1)
# memory usage: 220.3+ KB

# %%
df_infected[df_infected['Province/State'] !=0 ]
# Out:
#                                                    Province/State        Lat  \
# Country/Region
# Australia       Australian Capital TerritoryNew South WalesNor...  -255.9695
# Canada          AlbertaBritish ColumbiaGrand PrincessManitobaN...   671.7607
# China           AnhuiBeijingChongqingFujianGansuGuangdongGuang...  1083.3367
# Denmark                                    Faroe IslandsGreenland   189.8634
# France          French GuianaFrench PolynesiaGuadeloupeMayotte...    91.3624
# Netherlands     ArubaCuracaoSint MaartenBonaire, Sint Eustatiu...   107.0417
# United Kingdom  BermudaCayman IslandsChannel IslandsGibraltarI...   270.0299
#
#                      Long  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# Country/Region
# Australia       1129.8623        0        0        0        0        4
# Canada         -1237.6289        0        0        0        0        1
# China           3684.4197      548      643      920     1406     2075
# Denmark          -40.0143        0        0        0        0        0
# France            59.7192        0        0        2        3        3
# Netherlands     -265.0278        0        0        0        0        0
# United Kingdom  -482.9247        0        0        0        0        0
#
#                 1/27/20  1/28/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  \
# Country/Region                    ...
# Australia             5        5  ...    7259    7265    7267    7274
# Canada                1        2  ...   96475   97178   97779   98241
# China              2877     5509  ...   84186   84191   84195   84198
# Denmark               0        0  ...   12124   12148   12162   12201
# France                3        4  ...  190759  191102  191313  191523
# Netherlands           0        0  ...   47541   47780   47945   48109
# United Kingdom        0        0  ...  286294  287621  288834  290581
#
#                 6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# Country/Region
# Australia          7285     7289     7294     7320     7335     7347
# Canada            98720    99159    99595   100043   100404   100763
# China             84209    84216    84228    84286    84335    84378
# Denmark           12216    12235    12299    12339    12393    12417
# France           192068   192493   193220   193746   194153   194305
# Netherlands       48294    48458    48668    48847    48990    49155
# United Kingdom   291588   292860   294402   295828   297342   298315
#
# [7 rows x 149 columns]

# %%
infected.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  6/6/20  6/7/20  6/8/20  6/9/20  6/10/20  \
# 0        0        0        0  ...   19551   20342   20917   21459    22142
# 1        0        0        0  ...    1232    1246    1263    1299     1341
# 2        0        0        0  ...   10050   10154   10265   10382    10484
# 3        0        0        0  ...     852     852     852     852      852
# 4        0        0        0  ...      88      91      92      96      113
#
#    6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# 0    22890    23546    24102    24766    25527
# 1     1385     1416     1464     1521     1590
# 2    10589    10698    10810    10919    11031
# 3      852      853      853      853      853
# 4      118      130      138      140      142
#
# [5 rows x 150 columns]

# %%
#we tested groupby worked well and gave us correct results
infected[infected['Country/Region'] == 'China']['1/22/20'].sum()
# Out:
# 548

# %%
df_recovered= recorved.groupby('Country/Region').sum()
df_deaths = deaths.groupby('Country/Region').sum()

# %%
df_infected.loc['China'].to_frame()
# Out:
#                                                             China
# Province/State  AnhuiBeijingChongqingFujianGansuGuangdongGuang...
# Lat                                                     1083.3367
# Long                                                    3684.4197
# 1/22/20                                                       548
# 1/23/20                                                       643
# ...                                                           ...
# 6/11/20                                                     84216
# 6/12/20                                                     84228
# 6/13/20                                                     84286
# 6/14/20                                                     84335
# 6/15/20                                                     84378
#
# [149 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,6)

# %%
df_infected.loc['China'][2:].plot()
df_deaths.loc['China'][2:].plot()
df_recovered.loc['China'][2:].plot()

plt.show()

# %%
df_infected.drop(columns=['Lat','Long','Province/State'],inplace=True)

# %%
df_infected.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/6/20  6/7/20  6/8/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...   19551   20342   20917
# Albania               0        0        0  ...    1232    1246    1263
# Algeria               0        0        0  ...   10050   10154   10265
# Andorra               0        0        0  ...     852     852     852
# Angola                0        0        0  ...      88      91      92
#
#                 6/9/20  6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# Country/Region
# Afghanistan      21459    22142    22890    23546    24102    24766    25527
# Albania           1299     1341     1385     1416     1464     1521     1590
# Algeria          10382    10484    10589    10698    10810    10919    11031
# Andorra            852      852      852      853      853      853      853
# Angola              96      113      118      130      138      140      142
#
# [5 rows x 146 columns]

# %%
df_deaths=df_deaths.drop(columns=['Lat','Long','Province/State'])
df_recovered=df_recovered.drop(columns=['Lat','Long','Province/State'])

# %%
df_deaths.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  6/6/20  6/7/20  6/8/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     327     357     369
# Albania               0        0        0  ...      34      34      34
# Algeria               0        0        0  ...     698     707     715
# Andorra               0        0        0  ...      51      51      51
# Angola                0        0        0  ...       4       4       4
#
#                 6/9/20  6/10/20  6/11/20  6/12/20  6/13/20  6/14/20  6/15/20
# Country/Region
# Afghanistan        384      405      426      446      451      471      478
# Albania             34       34       35       36       36       36       36
# Algeria            724      732      741      751      760      767      777
# Andorra             51       51       51       51       51       51       51
# Angola               4        4        5        5        6        6        6
#
# [5 rows x 146 columns]

# %%
def make_frame(country:str):
    """ Take country name as parameter,return infected,recovered,deaths values as timeseries
        pd.DataFrame()
    """
    
    df = pd.DataFrame({
        'infected': df_infected.loc[country],
        'recorved' : df_recovered.loc[country],
        'deaths' : df_deaths.loc[country]
    })
    df.index = pd.to_datetime(df.index , format = '%m/%d/%y')
    return df

# %%
df_us =make_frame('US')

# %%
df_us.head()
# Out:
#             infected  recorved  deaths
# 2020-01-22         1         0       0
# 2020-01-23         1         0       0
# 2020-01-24         2         0       0
# 2020-01-25         2         0       0
# 2020-01-26         5         0       0

# %%
df_us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 146 entries, 2020-01-22 to 2020-06-15
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   infected  146 non-null    int64
#  1   recorved  146 non-null    int64
#  2   deaths    146 non-null    int64
# dtypes: int64(3)
# memory usage: 4.6 KB

# %%
df_us.plot()
plt.show()

# %%
df_us['new_infected'] = df_us['infected'].diff()

# %%
df_us.head()
# Out:
#             infected  recorved  deaths  new_infected
# 2020-01-22         1         0       0           NaN
# 2020-01-23         1         0       0           0.0
# 2020-01-24         2         0       0           1.0
# 2020-01-25         2         0       0           0.0
# 2020-01-26         5         0       0           3.0

# %%
df_us['new_infected'].plot()
plt.show()

# %%
df_us[df_us.index.year == 2020]['new_infected'].plot()
# Out:
# <Axes: >

# %%
df_us[(df_us.index.year == 2020) & (df_us.index.month==5)]['new_infected'].plot()
# Out:
# <Axes: >

# %%
df_us['new_infected_avg'] = df_us['new_infected'].rolling(window=7).mean()

# %%
df_us['new_infected_avg'].plot()
plt.show()

# %%
countries_dataset_url = base_url + "UID_ISO_FIPS_LookUp_Table.csv"
countries = pd.read_csv(countries_dataset_url)

# %%
countries.shape
# Out:
# (4021, 12)

# %%
countries[countries['Country_Region'] == 'US']
# Out:
#            UID iso2 iso3  code3     FIPS      Admin2  \
# 697        840   US  USA  840.0      NaN         NaN
# 698         16   AS  ASM   16.0     60.0         NaN
# 699        316   GU  GUM  316.0     66.0         NaN
# 700        580   MP  MNP  580.0     69.0         NaN
# 701        850   VI  VIR  850.0     78.0         NaN
# ...        ...  ...  ...    ...      ...         ...
# 4016  84056037   US  USA  840.0  56037.0  Sweetwater
# 4017  84056039   US  USA  840.0  56039.0       Teton
# 4018  84056041   US  USA  840.0  56041.0       Uinta
# 4019  84056043   US  USA  840.0  56043.0    Washakie
# 4020  84056045   US  USA  840.0  56045.0      Weston
#
#                 Province_State Country_Region        Lat       Long_  \
# 697                        NaN             US  40.000000 -100.000000
# 698             American Samoa             US -14.271000 -170.132000
# 699                       Guam             US  13.444300  144.793700
# 700   Northern Mariana Islands             US  15.097900  145.673900
# 701             Virgin Islands             US  18.335800  -64.896300
# ...                        ...            ...        ...         ...
# 4016                   Wyoming             US  41.659439 -108.882788
# 4017                   Wyoming             US  43.935225 -110.589080
# 4018                   Wyoming             US  41.287818 -110.547578
# 4019                   Wyoming             US  43.904516 -107.680187
# 4020                   Wyoming             US  43.839612 -104.567488
#
#                       Combined_Key   Population
# 697                             US  329466283.0
# 698             American Samoa, US      55641.0
# 699                       Guam, US     164229.0
# 700   Northern Mariana Islands, US      55144.0
# 701             Virgin Islands, US     107268.0
# ...                            ...          ...
# 4016       Sweetwater, Wyoming, US      42343.0
# 4017            Teton, Wyoming, US      23464.0
# 4018            Uinta, Wyoming, US      20226.0
# 4019         Washakie, Wyoming, US       7805.0
# 4020           Weston, Wyoming, US       6927.0
#
# [3324 rows x 12 columns]

# %%
countries[(countries['Country_Region']== 'US') & (countries['Province_State'].isna())]
# Out:
#      UID iso2 iso3  code3  FIPS Admin2 Province_State Country_Region   Lat  \
# 697  840   US  USA  840.0   NaN    NaN            NaN             US  40.0
#
#      Long_ Combined_Key   Population
# 697 -100.0           US  329466283.0

# %%
countries[(countries['Country_Region']== 'US') & (countries['Province_State'].isna())]['Population']
# Out:
# 697    329466283.0
# Name: Population, dtype: float64

# %%
pop_us=countries[(countries['Country_Region']== 'US') & (countries['Province_State'].isna())]['Population'].iloc[0]

# %%
pop_us
# Out:
# 329466283.0

# %%
df_us
# Out:
#             infected  recorved  deaths  new_infected  new_infected_avg
# 2020-01-22         1         0       0           NaN               NaN
# 2020-01-23         1         0       0           0.0               NaN
# 2020-01-24         2         0       0           1.0               NaN
# 2020-01-25         2         0       0           0.0               NaN
# 2020-01-26         5         0       0           3.0               NaN
# ...              ...       ...     ...           ...               ...
# 2020-06-11   2023590    540292  113823       22888.0      20721.000000
# 2020-06-12   2048986    547386  114669       25396.0      20733.142857
# 2020-06-13   2074526    556606  115436       25540.0      21141.142857
# 2020-06-14   2094058    561816  115732       19532.0      21392.714286
# 2020-06-15   2114026    576334  116127       19968.0      21749.285714
#
# [146 rows x 5 columns]

# %%
df_us['pop_infected'] = df_us['infected'] * 100 / pop_us

# %%
df_us
# Out:
#             infected  recorved  deaths  new_infected  new_infected_avg  \
# 2020-01-22         1         0       0           NaN               NaN
# 2020-01-23         1         0       0           0.0               NaN
# 2020-01-24         2         0       0           1.0               NaN
# 2020-01-25         2         0       0           0.0               NaN
# 2020-01-26         5         0       0           3.0               NaN
# ...              ...       ...     ...           ...               ...
# 2020-06-11   2023590    540292  113823       22888.0      20721.000000
# 2020-06-12   2048986    547386  114669       25396.0      20733.142857
# 2020-06-13   2074526    556606  115436       25540.0      21141.142857
# 2020-06-14   2094058    561816  115732       19532.0      21392.714286
# 2020-06-15   2114026    576334  116127       19968.0      21749.285714
#
#             pop_infected
# 2020-01-22  3.035212e-07
# 2020-01-23  3.035212e-07
# 2020-01-24  6.070424e-07
# 2020-01-25  6.070424e-07
# 2020-01-26  1.517606e-06
# ...                  ...
# 2020-06-11  6.142025e-01
# 2020-06-12  6.219107e-01
# 2020-06-13  6.296626e-01
# 2020-06-14  6.355910e-01
# 2020-06-15  6.416517e-01
#
# [146 rows x 6 columns]

# %%
df_us['pop_infected'].plot()
# Out:
# <Axes: >

# %%
#The basic reproduction number 
df_us['Rt'] = df_us['new_infected'].rolling(8).apply(lambda x : x[4:].sum() /x[:4].sum())

# %%
df_us
# Out:
#             infected  recorved  deaths  new_infected  new_infected_avg  \
# 2020-01-22         1         0       0           NaN               NaN
# 2020-01-23         1         0       0           0.0               NaN
# 2020-01-24         2         0       0           1.0               NaN
# 2020-01-25         2         0       0           0.0               NaN
# 2020-01-26         5         0       0           3.0               NaN
# ...              ...       ...     ...           ...               ...
# 2020-06-11   2023590    540292  113823       22888.0      20721.000000
# 2020-06-12   2048986    547386  114669       25396.0      20733.142857
# 2020-06-13   2074526    556606  115436       25540.0      21141.142857
# 2020-06-14   2094058    561816  115732       19532.0      21392.714286
# 2020-06-15   2114026    576334  116127       19968.0      21749.285714
#
#             pop_infected        Rt
# 2020-01-22  3.035212e-07       NaN
# 2020-01-23  3.035212e-07       NaN
# 2020-01-24  6.070424e-07       NaN
# 2020-01-25  6.070424e-07       NaN
# 2020-01-26  1.517606e-06       NaN
# ...                  ...       ...
# 2020-06-11  6.142025e-01  0.910637
# 2020-06-12  6.219107e-01  1.047659
# 2020-06-13  6.296626e-01  1.245271
# 2020-06-14  6.355910e-01  1.258778
# 2020-06-15  6.416517e-01  1.140702
#
# [146 rows x 7 columns]

# %%
df_us['Rt'].plot()
# Out:
# <Axes: >

# %%
#na ve inf degerler için neler yapılabilir
#log değerler alınabilir
#virgülden sonra basamak sayısını azaltmak 
#eksik verileri tamamlamak
#eksik veriyi doldurmak için pandas metodları bakmak

# %%
df_us['Rt'].replace(np.inf,np.nan).fillna(method='bfill')
# Out:
# 2020-01-22    0.000000
# 2020-01-23    0.000000
# 2020-01-24    0.000000
# 2020-01-25    0.000000
# 2020-01-26    0.000000
#                 ...
# 2020-06-11    0.910637
# 2020-06-12    1.047659
# 2020-06-13    1.245271
# 2020-06-14    1.258778
# 2020-06-15    1.140702
# Name: Rt, Length: 146, dtype: float64

# %%
df_us['Rt'].replace(np.inf,np.nan).bfill()
# Out:
# 2020-01-22    0.000000
# 2020-01-23    0.000000
# 2020-01-24    0.000000
# 2020-01-25    0.000000
# 2020-01-26    0.000000
#                 ...
# 2020-06-11    0.910637
# 2020-06-12    1.047659
# 2020-06-13    1.245271
# 2020-06-14    1.258778
# 2020-06-15    1.140702
# Name: Rt, Length: 146, dtype: float64

# %%
rt_array=df_us[df_us.index < '2020-06-01']['Rt'].replace(np.inf,np.nan).bfill()

# %%
rt_array
# Out:
# 2020-01-22    0.000000
# 2020-01-23    0.000000
# 2020-01-24    0.000000
# 2020-01-25    0.000000
# 2020-01-26    0.000000
#                 ...
# 2020-05-27    0.809279
# 2020-05-28    0.856214
# 2020-05-29    0.986176
# 2020-05-30    1.118134
# 2020-05-31    1.191314
# Name: Rt, Length: 131, dtype: float64

# %%
rt_array.plot()
# Out:
# <Axes: >

# %%
rt_array.plot()
plt.ylim([0,6])
# Out:
# (0.0, 6.0)

# %%
rt_array.plot()
plt.ylim([0,6])
plt.axhline(1,color='red',linestyle='dotted')

# %%
df_us.head()
# Out:
#             infected  recorved  deaths  new_infected  new_infected_avg  \
# 2020-01-22         1         0       0           NaN               NaN
# 2020-01-23         1         0       0           0.0               NaN
# 2020-01-24         2         0       0           1.0               NaN
# 2020-01-25         2         0       0           0.0               NaN
# 2020-01-26         5         0       0           3.0               NaN
#
#             pop_infected  Rt
# 2020-01-22  3.035212e-07 NaN
# 2020-01-23  3.035212e-07 NaN
# 2020-01-24  6.070424e-07 NaN
# 2020-01-25  6.070424e-07 NaN
# 2020-01-26  1.517606e-06 NaN

# %%
df_us['new_infected'].diff().plot()
# Out:
# <Axes: >

# %%
df_us['new_infected'].diff().rolling(7).mean().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### TODOs:
# - see the spread of pandemic in different countries.
# - plot Rt graphs in different countries side by side or in the same graph
# - chech correlation between deaths and recoveries
# - compare recoveries between countries
# - are they any outliers (anomalies)
